# %% [markdown]
# # CONTAINER LEVEL MODEL TRAINING

# %% [markdown]
# ### CONFIG VARS

# %%
from utils import *
import cv2
from shapely.geometry import Polygon, Point, GeometryCollection
from ultralytics import YOLO

# %%
DATASET_PATH="../Datasets/Dataset_ContainerLevel"
PREPROCESSED_PATH="../Preprocessed_Datasets/ContainerLevel"
AUGMENTED_PATH="../Augmented_Datasets/ContainerLevel"
AUGMENTED_PATH_TRAIN_EX="../Augmented_Datasets/ContainerLevel_train" # Data exclusively for training, not validating
YOLO_PATH="../YOLO_Datasets/ContainerLevel"
YOLO_PATH_TRAIN_EX="../YOLO_Datasets/ContainerLevel_train" # Data exclusively for training, not validating

# %% [markdown]
# ### AUGMENTATION

# %% [markdown]
# For this model we will apply the following augmentation techniques:
# - Hue transformations (-100º to +100º)
# - Contrast inversion (To simulate dark and light modes)

# %%
resize_dataset_images(DATASET_PATH, AUGMENTED_PATH, 640, 360)

# %%
hue_augmentation(AUGMENTED_PATH, AUGMENTED_PATH_TRAIN_EX, 0.15, 100)

# %%
contrast_inversion_augmentation(AUGMENTED_PATH, AUGMENTED_PATH_TRAIN_EX, 0.15)

# %%
# Add the augmented data to the train exclusively folder
for file in os.listdir(AUGMENTED_PATH):
    shutil.copy(os.path.join(AUGMENTED_PATH, file), AUGMENTED_PATH_TRAIN_EX)

# %% [markdown]
# ### FORMAT CONVERSION
#
# Up to now, we have treated with labelme format datasets, but we need to convert it to YOLOv8 format if we want to train
# a model, which has the following format:
#
# ```
# YOLOv8_Dataset/
# ├── data.yaml
# ├── train/
# │   ├── images/
# │   │   ├── img1.jpg
# │   │   ├── img2.jpg
# │   │   └── ...
# │   ├── labels/
# │   │   ├── img1.txt
# │   │   ├── img2.txt
# │   │   └── ...
# ├── valid/
# │   ├── images/
# │   │   ├── img1.jpg
# │   │   ├── img2.jpg
# │   │   └── ...
# │   ├── labels/
# │   │   ├── img1.txt
# │   │   ├── img2.txt
# │   │   └── ...
# └── test/ (OPTIONAL)
#     ├── images/
#     │   ├── img1.jpg
#     │   ├── img2.jpg
#     │   └── ...
#     └── labels/
#         ├── img1.txt
#         ├── img2.txt
#         └── ...
# ```
#
# The format of the data.yml file is:
# ```
# path: <path_to_dataset_root_dit>
# train: <path_to_train_images>
# val: <path_to_validation_images>
# test: <path_to_test_images> (OPTIONAL)
#
# nc: <number_of_classes>
# names: ['class1', 'class2', 'class3', ...]
# ```
#
# The labels for Instance segmentation have the following format for each annotation:
# ```
# <class-index> <x1> <y1> <x2> <y2> ... <xn> <yn>
# ```

# %%
labelme_to_yolo(AUGMENTED_PATH_TRAIN_EX, YOLO_PATH_TRAIN_EX, 0.7,[
                "TabActive",
                "TabInactive",
                "Sidebar",
                "Navbar",
                "Container",
                "Image",
                "BrowserURLInput",
                ], "seg")

# %% [markdown]
# ### TRAIN

# %% [markdown]
# We will perform fine-tuning over the mobile-sam model using the hyperparameter tuning provided by Ultralytics to get the
# best results we can. Since this is a non-standard dataset in terms of object features it is not clear what are the values
# we should use.
#
# We will also configure the training to not do any augmentation over the train set

# %%
from ultralytics import YOLO
# Initialize the YOLO model
model = YOLO("yolov8n-seg")

# %%
import torch
# check if CUDA is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using {} device'.format(device))
# Out:
# Using cuda device

# %%
# Tune hyperparameters on dataset for 30 epochs
model.tune(data="../YOLO_Datasets/ContainerLevel_train/data.yaml", workers=1, epochs=100, iterations=50, patience=15, optimizer='AdamW', plots=False, save=True, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, fliplr=0.0)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs\segment\tune10'
# Tuner:  Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 1/50 iterations complete  (994.19s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 2/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.00058, 'warmup_epochs': 2.94266, 'warmup_momentum': 0.81807, 'box': 8.6972, 'cls': 0.56962, 'dfl': 1.32528, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10011, 'scale': 0.54285, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.98028, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 2/50 iterations complete  (2056.56s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 3/50 with hyperparameters: {'lr0': 0.01193, 'lrf': 0.01, 'momentum': 0.97001, 'weight_decay': 0.00044, 'warmup_epochs': 3.50465, 'warmup_momentum': 0.72746, 'box': 7.31586, 'cls': 0.5, 'dfl': 1.67114, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.0895, 'scale': 0.44363, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 3/50 iterations complete  (3062.55s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 4/50 with hyperparameters: {'lr0': 0.01082, 'lrf': 0.0083, 'momentum': 0.96083, 'weight_decay': 0.00041, 'warmup_epochs': 2.56758, 'warmup_momentum': 0.83526, 'box': 7.06168, 'cls': 0.5, 'dfl': 1.44693, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09765, 'scale': 0.40742, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.93801, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 4/50 iterations complete  (4060.69s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 5/50 with hyperparameters: {'lr0': 0.01085, 'lrf': 0.0083, 'momentum': 0.96115, 'weight_decay': 0.0004, 'warmup_epochs': 2.59507, 'warmup_momentum': 0.83526, 'box': 7.10549, 'cls': 0.5, 'dfl': 1.43916, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09765, 'scale': 0.40851, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.93801, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 5/50 iterations complete  (5065.35s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 6/50 with hyperparameters: {'lr0': 0.01038, 'lrf': 0.00941, 'momentum': 0.98, 'weight_decay': 0.00041, 'warmup_epochs': 2.22703, 'warmup_momentum': 0.90569, 'box': 6.54063, 'cls': 0.5499, 'dfl': 1.44693, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10099, 'scale': 0.41344, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.95371, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 6/50 iterations complete  (6246.94s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 7/50 with hyperparameters: {'lr0': 0.01025, 'lrf': 0.00779, 'momentum': 0.97081, 'weight_decay': 0.00043, 'warmup_epochs': 2.13074, 'warmup_momentum': 0.83526, 'box': 6.1579, 'cls': 0.46891, 'dfl': 1.42839, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09597, 'scale': 0.43238, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.95599, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 7/50 iterations complete  (7384.45s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 8/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01043, 'momentum': 0.91913, 'weight_decay': 0.00052, 'warmup_epochs': 2.8666, 'warmup_momentum': 0.81483, 'box': 7.78967, 'cls': 0.48751, 'dfl': 1.56725, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09623, 'scale': 0.47452, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.98653, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 8/50 iterations complete  (8306.38s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 9/50 with hyperparameters: {'lr0': 0.01013, 'lrf': 0.00944, 'momentum': 0.98, 'weight_decay': 0.00039, 'warmup_epochs': 2.21449, 'warmup_momentum': 0.95, 'box': 6.54063, 'cls': 0.58855, 'dfl': 1.44693, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09927, 'scale': 0.43072, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.8493, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 9/50 iterations complete  (9200.20s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 10/50 with hyperparameters: {'lr0': 0.01036, 'lrf': 0.00941, 'momentum': 0.98, 'weight_decay': 0.00041, 'warmup_epochs': 2.23131, 'warmup_momentum': 0.90039, 'box': 6.53408, 'cls': 0.54758, 'dfl': 1.43905, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.1012, 'scale': 0.41344, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.95371, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 10/50 iterations complete  (10054.05s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 11/50 with hyperparameters: {'lr0': 0.00917, 'lrf': 0.00718, 'momentum': 0.96319, 'weight_decay': 0.00044, 'warmup_epochs': 2.13074, 'warmup_momentum': 0.83526, 'box': 7.16064, 'cls': 0.47705, 'dfl': 1.41626, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09597, 'scale': 0.47814, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.95599, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 11/50 iterations complete  (11086.08s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 12/50 with hyperparameters: {'lr0': 0.01038, 'lrf': 0.00941, 'momentum': 0.98, 'weight_decay': 0.00049, 'warmup_epochs': 2.22703, 'warmup_momentum': 0.90569, 'box': 6.54063, 'cls': 0.64914, 'dfl': 1.44693, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08248, 'scale': 0.49335, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.94241, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 12/50 iterations complete  (11984.42s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 13/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01004, 'momentum': 0.94424, 'weight_decay': 0.00051, 'warmup_epochs': 3.03855, 'warmup_momentum': 0.80565, 'box': 7.45103, 'cls': 0.47028, 'dfl': 1.48986, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10064, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 13/50 iterations complete  (12808.94s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 14/50 with hyperparameters: {'lr0': 0.00997, 'lrf': 0.00941, 'momentum': 0.98, 'weight_decay': 0.00035, 'warmup_epochs': 1.89637, 'warmup_momentum': 0.90569, 'box': 6.54063, 'cls': 0.58944, 'dfl': 1.44693, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10099, 'scale': 0.41344, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.92839, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 14/50 iterations complete  (13662.31s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 15/50 with hyperparameters: {'lr0': 0.00877, 'lrf': 0.00836, 'momentum': 0.98, 'weight_decay': 0.00043, 'warmup_epochs': 2.32325, 'warmup_momentum': 0.73422, 'box': 7.6631, 'cls': 0.59377, 'dfl': 1.65555, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10513, 'scale': 0.53874, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.95371, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 15/50 iterations complete  (14536.12s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.63615 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.5968, 'metrics/recall(B)': 0.51084, 'metrics/mAP50(B)': 0.55095, 'metrics/mAP50-95(B)': 0.36888, 'metrics/precision(M)': 0.55787, 'metrics/recall(M)': 0.46017, 'metrics/mAP50(M)': 0.47763, 'metrics/mAP50-95(M)': 0.22367, 'val/box_loss': 1.3066, 'val/seg_loss': 1.97065, 'val/cls_loss': 1.88659, 'val/dfl_loss': 1.1663, 'fitness': 0.63615}
# Tuner: Best fitness model is runs\segment\train37
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 16/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.00917, 'momentum': 0.94884, 'weight_decay': 0.00049, 'warmup_epochs': 3.0, 'warmup_momentum': 0.90476, 'box': 7.5, 'cls': 0.45418, 'dfl': 1.28456, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09577, 'scale': 0.57168, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.88027, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 16/50 iterations complete  (15396.15s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 17/50 with hyperparameters: {'lr0': 0.01007, 'lrf': 0.01023, 'momentum': 0.98, 'weight_decay': 0.00039, 'warmup_epochs': 1.87164, 'warmup_momentum': 0.87415, 'box': 6.54063, 'cls': 0.64101, 'dfl': 1.35814, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09998, 'scale': 0.41344, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.96243, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 17/50 iterations complete  (16282.97s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 18/50 with hyperparameters: {'lr0': 0.01038, 'lrf': 0.0094, 'momentum': 0.98, 'weight_decay': 0.00049, 'warmup_epochs': 2.49197, 'warmup_momentum': 0.91698, 'box': 5.8706, 'cls': 0.5144, 'dfl': 1.29663, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10099, 'scale': 0.41344, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.92882, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 18/50 iterations complete  (17141.98s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 19/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.89982, 'weight_decay': 0.0006, 'warmup_epochs': 3.13273, 'warmup_momentum': 0.94878, 'box': 7.26467, 'cls': 0.5, 'dfl': 1.22189, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10716, 'scale': 0.42097, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 19/50 iterations complete  (18037.02s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 20/50 with hyperparameters: {'lr0': 0.01086, 'lrf': 0.00921, 'momentum': 0.98, 'weight_decay': 0.00041, 'warmup_epochs': 2.28955, 'warmup_momentum': 0.88541, 'box': 6.54063, 'cls': 0.55639, 'dfl': 1.49942, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09919, 'scale': 0.40938, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.92135, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 20/50 iterations complete  (18847.38s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 21/50 with hyperparameters: {'lr0': 0.01052, 'lrf': 0.00925, 'momentum': 0.95348, 'weight_decay': 0.0005, 'warmup_epochs': 2.94026, 'warmup_momentum': 0.93221, 'box': 7.29355, 'cls': 0.43508, 'dfl': 1.23715, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09201, 'scale': 0.59484, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.89499, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 21/50 iterations complete  (19694.26s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 22/50 with hyperparameters: {'lr0': 0.01013, 'lrf': 0.00824, 'momentum': 0.87123, 'weight_decay': 0.00059, 'warmup_epochs': 3.13273, 'warmup_momentum': 0.94878, 'box': 8.12994, 'cls': 0.54072, 'dfl': 1.25356, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10716, 'scale': 0.46312, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.95794, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 22/50 iterations complete  (20617.47s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 23/50 with hyperparameters: {'lr0': 0.01035, 'lrf': 0.01005, 'momentum': 0.98, 'weight_decay': 0.00037, 'warmup_epochs': 2.21536, 'warmup_momentum': 0.90569, 'box': 6.3717, 'cls': 0.52877, 'dfl': 1.46924, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10779, 'scale': 0.36611, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.95371, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 23/50 iterations complete  (21437.77s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 24/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01086, 'momentum': 0.87256, 'weight_decay': 0.00061, 'warmup_epochs': 2.76443, 'warmup_momentum': 0.71473, 'box': 7.1793, 'cls': 0.42987, 'dfl': 1.18713, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.1053, 'scale': 0.37823, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 24/50 iterations complete  (22299.16s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 25/50 with hyperparameters: {'lr0': 0.00995, 'lrf': 0.00917, 'momentum': 0.98, 'weight_decay': 0.00053, 'warmup_epochs': 3.0, 'warmup_momentum': 0.90476, 'box': 8.97101, 'cls': 0.46382, 'dfl': 1.51054, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.11953, 'scale': 0.45004, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.92918, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 25/50 iterations complete  (23188.37s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 26/50 with hyperparameters: {'lr0': 0.01045, 'lrf': 0.00884, 'momentum': 0.88905, 'weight_decay': 0.00049, 'warmup_epochs': 3.14874, 'warmup_momentum': 0.76879, 'box': 7.26831, 'cls': 0.47504, 'dfl': 1.28456, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10095, 'scale': 0.57168, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.87037, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 26/50 iterations complete  (24100.71s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 27/50 with hyperparameters: {'lr0': 0.01068, 'lrf': 0.00901, 'momentum': 0.94884, 'weight_decay': 0.00052, 'warmup_epochs': 3.20296, 'warmup_momentum': 0.91444, 'box': 7.13261, 'cls': 0.39985, 'dfl': 1.24656, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08488, 'scale': 0.56208, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.78333, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 27/50 iterations complete  (24896.99s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 28/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.00917, 'momentum': 0.9681, 'weight_decay': 0.00048, 'warmup_epochs': 2.79206, 'warmup_momentum': 0.83481, 'box': 7.18202, 'cls': 0.45418, 'dfl': 1.20633, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10084, 'scale': 0.57168, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.88915, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 28/50 iterations complete  (25724.35s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 29/50 with hyperparameters: {'lr0': 0.00908, 'lrf': 0.00994, 'momentum': 0.98, 'weight_decay': 0.0004, 'warmup_epochs': 2.22703, 'warmup_momentum': 0.90569, 'box': 6.54063, 'cls': 0.56758, 'dfl': 1.44693, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10376, 'scale': 0.38889, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.92861, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 29/50 iterations complete  (26576.83s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 30/50 with hyperparameters: {'lr0': 0.01073, 'lrf': 0.00762, 'momentum': 0.98, 'weight_decay': 0.00041, 'warmup_epochs': 1.93998, 'warmup_momentum': 0.89285, 'box': 6.54063, 'cls': 0.5203, 'dfl': 1.16954, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08949, 'scale': 0.41344, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.95967, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 30/50 iterations complete  (27396.11s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 31/50 with hyperparameters: {'lr0': 0.00983, 'lrf': 0.00895, 'momentum': 0.93185, 'weight_decay': 0.00048, 'warmup_epochs': 3.05231, 'warmup_momentum': 0.9175, 'box': 6.77962, 'cls': 0.45335, 'dfl': 1.30247, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08981, 'scale': 0.56882, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.89704, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 31/50 iterations complete  (28238.43s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# ...
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 41/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.00977, 'momentum': 0.97747, 'weight_decay': 0.00049, 'warmup_epochs': 3.0, 'warmup_momentum': 0.95, 'box': 7.28117, 'cls': 0.39736, 'dfl': 1.24075, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.11444, 'scale': 0.63784, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.89338, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 41/50 iterations complete  (37028.56s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 42/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.00797, 'momentum': 0.97927, 'weight_decay': 0.00038, 'warmup_epochs': 1.95275, 'warmup_momentum': 0.76447, 'box': 9.0223, 'cls': 0.45418, 'dfl': 1.38645, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.11531, 'scale': 0.57168, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.88027, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 42/50 iterations complete  (37871.75s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 43/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01038, 'momentum': 0.89151, 'weight_decay': 0.00054, 'warmup_epochs': 3.09979, 'warmup_momentum': 0.95, 'box': 7.26467, 'cls': 0.48864, 'dfl': 1.22189, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.0943, 'scale': 0.41625, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.84578, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 43/50 iterations complete  (38725.32s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 44/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.00994, 'momentum': 0.94974, 'weight_decay': 0.0005, 'warmup_epochs': 2.8737, 'warmup_momentum': 0.90476, 'box': 6.77972, 'cls': 0.44177, 'dfl': 1.29663, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09014, 'scale': 0.57306, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.95376, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 44/50 iterations complete  (39568.67s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 45/50 with hyperparameters: {'lr0': 0.00768, 'lrf': 0.00455, 'momentum': 0.88903, 'weight_decay': 0.00046, 'warmup_epochs': 3.23581, 'warmup_momentum': 0.811, 'box': 7.5, 'cls': 0.52214, 'dfl': 1.45959, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10433, 'scale': 0.58092, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.69579, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 45/50 iterations complete  (40361.05s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 46/50 with hyperparameters: {'lr0': 0.01008, 'lrf': 0.00994, 'momentum': 0.95861, 'weight_decay': 0.00051, 'warmup_epochs': 2.9067, 'warmup_momentum': 0.89132, 'box': 6.62214, 'cls': 0.42351, 'dfl': 1.31386, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09102, 'scale': 0.57615, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 46/50 iterations complete  (41119.06s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 47/50 with hyperparameters: {'lr0': 0.00895, 'lrf': 0.00773, 'momentum': 0.93389, 'weight_decay': 0.00049, 'warmup_epochs': 2.9549, 'warmup_momentum': 0.7206, 'box': 9.44924, 'cls': 0.479, 'dfl': 1.42824, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09946, 'scale': 0.57168, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.74436, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 47/50 iterations complete  (41907.19s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 48/50 with hyperparameters: {'lr0': 0.0085, 'lrf': 0.0079, 'momentum': 0.92278, 'weight_decay': 0.00049, 'warmup_epochs': 2.92763, 'warmup_momentum': 0.72751, 'box': 9.44924, 'cls': 0.48533, 'dfl': 1.42824, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09776, 'scale': 0.57168, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.77574, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 48/50 iterations complete  (42768.27s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 49/50 with hyperparameters: {'lr0': 0.01269, 'lrf': 0.00835, 'momentum': 0.98, 'weight_decay': 0.00051, 'warmup_epochs': 2.9109, 'warmup_momentum': 0.86524, 'box': 7.69931, 'cls': 0.38258, 'dfl': 1.48071, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09861, 'scale': 0.50812, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.76826, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 49/50 iterations complete  (43561.67s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 50/50 with hyperparameters: {'lr0': 0.00895, 'lrf': 0.00708, 'momentum': 0.92164, 'weight_decay': 0.00042, 'warmup_epochs': 2.64626, 'warmup_momentum': 0.7206, 'box': 9.69743, 'cls': 0.45584, 'dfl': 1.41629, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10447, 'scale': 0.59434, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.80745, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune10\tune_scatter_plots.png
# Saved runs\segment\tune10\tune_fitness.png
#
# Tuner: 50/50 iterations complete  (44352.92s)
# Tuner: Results saved to runs\segment\tune10
# Tuner: Best fitness=0.73015 observed at iteration 16
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.58428, 'metrics/recall(B)': 0.51964, 'metrics/mAP50(B)': 0.56286, 'metrics/mAP50-95(B)': 0.40567, 'metrics/precision(M)': 0.54922, 'metrics/recall(M)': 0.51098, 'metrics/mAP50(M)': 0.53682, 'metrics/mAP50-95(M)': 0.28342, 'val/box_loss': 1.23332, 'val/seg_loss': 2.41838, 'val/cls_loss': 1.46209, 'val/dfl_loss': 1.00455, 'fitness': 0.73015}
# Tuner: Best fitness model is runs\segment\train52
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.00917
# momentum: 0.94884
# weight_decay: 0.00049
# warmup_epochs: 3.0
# warmup_momentum: 0.90476
# box: 7.5
# cls: 0.45418
# dfl: 1.28456
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09577
# scale: 0.57168
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.88027
# mixup: 0.0
# copy_paste: 0.0

# %%
model = YOLO("runs/detect/tune10/weights/best.pt")

# %%
# Validate the model
metrics = model.val(workers=1)  # no arguments needed, dataset and settings remembered
# Out:
# Ultralytics YOLOv8.0.208  Python-3.9.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4096MiB)
# Model summary (fused): 168 layers, 3007013 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\Code\Screen2SOM-Training\YOLO_Datasets\ContainerLevel_train\val\labels.cache... 38 images, 1 backgrounds, 0 corrupt: 100%|██████████| 38/38 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  1.75it/s]
#                    all         38        442      0.857      0.771      0.837      0.643
#              TabActive         38         28      0.876      0.857      0.943      0.789
#            TabInactive         38         58      0.953      0.703      0.863      0.654
#                Sidebar         38         18      0.937      0.827      0.898      0.828
#                 Navbar         38         19       0.74       0.75      0.784       0.52
#              Container         38        145       0.65      0.602      0.589      0.488
#                  Image         38        147       0.86      0.803      0.843      0.575
#        BrowserURLInput         38         27      0.981      0.852      0.937      0.649
# Speed: 2.8ms preprocess, 16.0ms inference, 0.0ms loss, 9.4ms postprocess per image
# Results saved to runs\detect\val4

# %%
metrics.seg.map    # map50-95
metrics.seg.map50  # map50
metrics.seg.map75  # map75
metrics.seg.maps   # a list contains map50-95 of each category
# Out:
# array([    0.19274,     0.32869,     0.40419,     0.39927,       0.561,     0.28032,     0.10029,     0.16814,     0.26469,     0.19651,     0.35886,     0.31838,     0.15703])

# %%
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# array([    0.44217,     0.57988,      0.5628,     0.66923,     0.72803,     0.39053,     0.33478,     0.53026,     0.41717,     0.49925,     0.55777,     0.43547,      0.2592])

# %%
inference = model("../YOLO_Datasets/Elementlevel_train/val/images/Captura de pantalla (44)_2.jpg", save=True)
# Out:
# image 1/1 d:\Code\Screen2SOM-Training\Training\..\YOLO_Datasets\Elementlevel_train\val\images\Captura de pantalla (44)_2.jpg: 384x640 33 WebIcons, 4 Icons, 3 BtnPills, 3 TextInputs, 2 Links, 29.0ms
# Speed: 3.0ms preprocess, 29.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\segment\predict

# %%
from ultralytics import SAM

model = SAM('mobile_sam.pt')

# %%
model.tune(
    data="../YOLO_Datasets/ContainerLevel_train/data.yaml",
    workers=1,
    epochs=100,
    iterations=50,
    patience=15,
    optimizer="AdamW",
    plots=False,
    save=True,
    hsv_h=0.0,
    hsv_s=0.0,
    hsv_v=0.0,
    fliplr=0.0,
)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs\detect\tune10'
# Tuner:  Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 1/50 iterations complete  (520.88s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.58822 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73157, 'metrics/recall(B)': 0.72583, 'metrics/mAP50(B)': 0.76763, 'metrics/mAP50-95(B)': 0.56829, 'val/box_loss': 0.93498, 'val/cls_loss': 1.04477, 'val/dfl_loss': 0.97088, 'fitness': 0.58822}
# Tuner: Best fitness model is runs\detect\train104
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 2/50 with hyperparameters: {'lr0': 0.01025, 'lrf': 0.00967, 'momentum': 0.93985, 'weight_decay': 0.0005, 'warmup_epochs': 2.95904, 'warmup_momentum': 0.84678, 'box': 7.39939, 'cls': 0.5, 'dfl': 1.57302, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.47158, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.96954, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 2/50 iterations complete  (979.57s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.60395 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.82647, 'metrics/recall(B)': 0.69668, 'metrics/mAP50(B)': 0.78734, 'metrics/mAP50-95(B)': 0.58357, 'val/box_loss': 0.89037, 'val/cls_loss': 1.0279, 'val/dfl_loss': 1.01212, 'fitness': 0.60395}
# Tuner: Best fitness model is runs\detect\train105
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01025
# lrf: 0.00967
# momentum: 0.93985
# weight_decay: 0.0005
# warmup_epochs: 2.95904
# warmup_momentum: 0.84678
# box: 7.39939
# cls: 0.5
# dfl: 1.57302
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.47158
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.96954
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 3/50 with hyperparameters: {'lr0': 0.01045, 'lrf': 0.00983, 'momentum': 0.91178, 'weight_decay': 0.0004, 'warmup_epochs': 2.95904, 'warmup_momentum': 0.84678, 'box': 7.42262, 'cls': 0.43052, 'dfl': 1.66606, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08966, 'scale': 0.47158, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.86586, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 3/50 iterations complete  (1087.71s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.60395 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.82647, 'metrics/recall(B)': 0.69668, 'metrics/mAP50(B)': 0.78734, 'metrics/mAP50-95(B)': 0.58357, 'val/box_loss': 0.89037, 'val/cls_loss': 1.0279, 'val/dfl_loss': 1.01212, 'fitness': 0.60395}
# Tuner: Best fitness model is runs\detect\train105
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01025
# lrf: 0.00967
# momentum: 0.93985
# weight_decay: 0.0005
# warmup_epochs: 2.95904
# warmup_momentum: 0.84678
# box: 7.39939
# cls: 0.5
# dfl: 1.57302
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.47158
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.96954
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 4/50 with hyperparameters: {'lr0': 0.01004, 'lrf': 0.00987, 'momentum': 0.93311, 'weight_decay': 0.0005, 'warmup_epochs': 2.96313, 'warmup_momentum': 0.79211, 'box': 7.49121, 'cls': 0.50638, 'dfl': 1.47056, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09977, 'scale': 0.50075, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 4/50 iterations complete  (1205.78s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.60395 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.82647, 'metrics/recall(B)': 0.69668, 'metrics/mAP50(B)': 0.78734, 'metrics/mAP50-95(B)': 0.58357, 'val/box_loss': 0.89037, 'val/cls_loss': 1.0279, 'val/dfl_loss': 1.01212, 'fitness': 0.60395}
# Tuner: Best fitness model is runs\detect\train105
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01025
# lrf: 0.00967
# momentum: 0.93985
# weight_decay: 0.0005
# warmup_epochs: 2.95904
# warmup_momentum: 0.84678
# box: 7.39939
# cls: 0.5
# dfl: 1.57302
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.47158
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.96954
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 5/50 with hyperparameters: {'lr0': 0.00999, 'lrf': 0.01007, 'momentum': 0.90231, 'weight_decay': 0.0005, 'warmup_epochs': 2.80566, 'warmup_momentum': 0.89338, 'box': 7.39939, 'cls': 0.5, 'dfl': 1.57302, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09504, 'scale': 0.54995, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.96954, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 5/50 iterations complete  (1661.57s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.60533 observed at iteration 5
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.79455, 'metrics/recall(B)': 0.69453, 'metrics/mAP50(B)': 0.77181, 'metrics/mAP50-95(B)': 0.58683, 'val/box_loss': 0.84671, 'val/cls_loss': 0.95602, 'val/dfl_loss': 1.00143, 'fitness': 0.60533}
# Tuner: Best fitness model is runs\detect\train108
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.00999
# lrf: 0.01007
# momentum: 0.90231
# weight_decay: 0.0005
# warmup_epochs: 2.80566
# warmup_momentum: 0.89338
# box: 7.39939
# cls: 0.5
# dfl: 1.57302
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09504
# scale: 0.54995
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.96954
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 6/50 with hyperparameters: {'lr0': 0.01166, 'lrf': 0.01007, 'momentum': 0.87649, 'weight_decay': 0.00061, 'warmup_epochs': 2.53384, 'warmup_momentum': 0.89338, 'box': 7.39939, 'cls': 0.44592, 'dfl': 1.41531, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09384, 'scale': 0.49715, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.82327, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 6/50 iterations complete  (2119.12s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.60533 observed at iteration 5
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.79455, 'metrics/recall(B)': 0.69453, 'metrics/mAP50(B)': 0.77181, 'metrics/mAP50-95(B)': 0.58683, 'val/box_loss': 0.84671, 'val/cls_loss': 0.95602, 'val/dfl_loss': 1.00143, 'fitness': 0.60533}
# Tuner: Best fitness model is runs\detect\train108
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.00999
# lrf: 0.01007
# momentum: 0.90231
# weight_decay: 0.0005
# warmup_epochs: 2.80566
# warmup_momentum: 0.89338
# box: 7.39939
# cls: 0.5
# dfl: 1.57302
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09504
# scale: 0.54995
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.96954
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 7/50 with hyperparameters: {'lr0': 0.01014, 'lrf': 0.01057, 'momentum': 0.91611, 'weight_decay': 0.00045, 'warmup_epochs': 2.86641, 'warmup_momentum': 0.82208, 'box': 7.11919, 'cls': 0.57735, 'dfl': 1.49413, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09591, 'scale': 0.45217, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.97542, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 7/50 iterations complete  (2419.25s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.60533 observed at iteration 5
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.79455, 'metrics/recall(B)': 0.69453, 'metrics/mAP50(B)': 0.77181, 'metrics/mAP50-95(B)': 0.58683, 'val/box_loss': 0.84671, 'val/cls_loss': 0.95602, 'val/dfl_loss': 1.00143, 'fitness': 0.60533}
# Tuner: Best fitness model is runs\detect\train108
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.00999
# lrf: 0.01007
# momentum: 0.90231
# weight_decay: 0.0005
# warmup_epochs: 2.80566
# warmup_momentum: 0.89338
# box: 7.39939
# cls: 0.5
# dfl: 1.57302
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09504
# scale: 0.54995
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.96954
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 8/50 with hyperparameters: {'lr0': 0.00909, 'lrf': 0.0104, 'momentum': 0.93985, 'weight_decay': 0.00047, 'warmup_epochs': 3.23932, 'warmup_momentum': 0.95, 'box': 6.26781, 'cls': 0.39983, 'dfl': 1.85741, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09416, 'scale': 0.47158, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.77636, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 8/50 iterations complete  (2886.11s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.60533 observed at iteration 5
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.79455, 'metrics/recall(B)': 0.69453, 'metrics/mAP50(B)': 0.77181, 'metrics/mAP50-95(B)': 0.58683, 'val/box_loss': 0.84671, 'val/cls_loss': 0.95602, 'val/dfl_loss': 1.00143, 'fitness': 0.60533}
# Tuner: Best fitness model is runs\detect\train108
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.00999
# lrf: 0.01007
# momentum: 0.90231
# weight_decay: 0.0005
# warmup_epochs: 2.80566
# warmup_momentum: 0.89338
# box: 7.39939
# cls: 0.5
# dfl: 1.57302
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09504
# scale: 0.54995
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.96954
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 9/50 with hyperparameters: {'lr0': 0.01005, 'lrf': 0.00956, 'momentum': 0.90231, 'weight_decay': 0.00048, 'warmup_epochs': 2.52489, 'warmup_momentum': 0.6791, 'box': 6.02493, 'cls': 0.5, 'dfl': 1.77993, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10225, 'scale': 0.5234, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.96954, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 9/50 iterations complete  (3336.06s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.60533 observed at iteration 5
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.79455, 'metrics/recall(B)': 0.69453, 'metrics/mAP50(B)': 0.77181, 'metrics/mAP50-95(B)': 0.58683, 'val/box_loss': 0.84671, 'val/cls_loss': 0.95602, 'val/dfl_loss': 1.00143, 'fitness': 0.60533}
# Tuner: Best fitness model is runs\detect\train108
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.00999
# lrf: 0.01007
# momentum: 0.90231
# weight_decay: 0.0005
# warmup_epochs: 2.80566
# warmup_momentum: 0.89338
# box: 7.39939
# cls: 0.5
# dfl: 1.57302
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09504
# scale: 0.54995
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.96954
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 10/50 with hyperparameters: {'lr0': 0.01182, 'lrf': 0.01422, 'momentum': 0.84031, 'weight_decay': 0.00067, 'warmup_epochs': 2.53384, 'warmup_momentum': 0.95, 'box': 5.44002, 'cls': 0.44592, 'dfl': 1.41531, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09324, 'scale': 0.49715, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.85294, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 10/50 iterations complete  (3783.16s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 11/50 with hyperparameters: {'lr0': 0.01399, 'lrf': 0.01686, 'momentum': 0.84061, 'weight_decay': 0.00062, 'warmup_epochs': 2.53384, 'warmup_momentum': 0.95, 'box': 5.47715, 'cls': 0.48353, 'dfl': 1.45416, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09305, 'scale': 0.55713, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.84695, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 11/50 iterations complete  (4267.13s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 12/50 with hyperparameters: {'lr0': 0.01182, 'lrf': 0.01254, 'momentum': 0.79835, 'weight_decay': 0.00067, 'warmup_epochs': 3.1507, 'warmup_momentum': 0.95, 'box': 5.44002, 'cls': 0.58208, 'dfl': 1.12919, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09324, 'scale': 0.60405, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.99682, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 12/50 iterations complete  (4739.94s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 13/50 with hyperparameters: {'lr0': 0.00991, 'lrf': 0.00967, 'momentum': 0.8355, 'weight_decay': 0.00059, 'warmup_epochs': 3.10714, 'warmup_momentum': 0.95, 'box': 5.5412, 'cls': 0.57568, 'dfl': 1.20941, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09939, 'scale': 0.60405, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.99682, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 13/50 iterations complete  (4861.65s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 14/50 with hyperparameters: {'lr0': 0.0101, 'lrf': 0.0091, 'momentum': 0.92195, 'weight_decay': 0.00051, 'warmup_epochs': 2.9635, 'warmup_momentum': 0.66016, 'box': 7.7992, 'cls': 0.59487, 'dfl': 1.4165, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09754, 'scale': 0.53149, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.91294, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 14/50 iterations complete  (5325.84s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 15/50 with hyperparameters: {'lr0': 0.01128, 'lrf': 0.01419, 'momentum': 0.8433, 'weight_decay': 0.00065, 'warmup_epochs': 2.6021, 'warmup_momentum': 0.95, 'box': 5.08345, 'cls': 0.40843, 'dfl': 1.53001, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08409, 'scale': 0.49338, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.85294, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 15/50 iterations complete  (5763.35s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 16/50 with hyperparameters: {'lr0': 0.01251, 'lrf': 0.01337, 'momentum': 0.79448, 'weight_decay': 0.00067, 'warmup_epochs': 3.1507, 'warmup_momentum': 0.92976, 'box': 5.57904, 'cls': 0.58208, 'dfl': 1.08774, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08894, 'scale': 0.56033, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.97189, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 16/50 iterations complete  (6199.32s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 17/50 with hyperparameters: {'lr0': 0.01188, 'lrf': 0.0143, 'momentum': 0.84016, 'weight_decay': 0.00066, 'warmup_epochs': 2.55124, 'warmup_momentum': 0.95, 'box': 5.44002, 'cls': 0.44287, 'dfl': 1.41338, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09289, 'scale': 0.49786, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.86052, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 17/50 iterations complete  (6634.21s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 18/50 with hyperparameters: {'lr0': 0.01182, 'lrf': 0.01223, 'momentum': 0.79835, 'weight_decay': 0.00064, 'warmup_epochs': 3.20986, 'warmup_momentum': 0.95, 'box': 5.47614, 'cls': 0.55992, 'dfl': 1.12919, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08938, 'scale': 0.61205, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 18/50 iterations complete  (7070.36s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 19/50 with hyperparameters: {'lr0': 0.00995, 'lrf': 0.01545, 'momentum': 0.75137, 'weight_decay': 0.00075, 'warmup_epochs': 2.62731, 'warmup_momentum': 0.95, 'box': 6.26431, 'cls': 0.45154, 'dfl': 1.41531, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10064, 'scale': 0.57604, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.62306, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 19/50 iterations complete  (7502.53s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 20/50 with hyperparameters: {'lr0': 0.0128, 'lrf': 0.01004, 'momentum': 0.88056, 'weight_decay': 0.00059, 'warmup_epochs': 2.78581, 'warmup_momentum': 0.94212, 'box': 5.62245, 'cls': 0.34378, 'dfl': 1.29124, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.07843, 'scale': 0.43481, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.9145, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 20/50 iterations complete  (7935.50s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 21/50 with hyperparameters: {'lr0': 0.01074, 'lrf': 0.01254, 'momentum': 0.8322, 'weight_decay': 0.00058, 'warmup_epochs': 3.1507, 'warmup_momentum': 0.94454, 'box': 5.46995, 'cls': 0.58208, 'dfl': 1.07364, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08044, 'scale': 0.52196, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 21/50 iterations complete  (8048.72s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 22/50 with hyperparameters: {'lr0': 0.01189, 'lrf': 0.01261, 'momentum': 0.79899, 'weight_decay': 0.00067, 'warmup_epochs': 3.13247, 'warmup_momentum': 0.95, 'box': 5.3648, 'cls': 0.59069, 'dfl': 1.13755, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09264, 'scale': 0.60178, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.99047, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 22/50 iterations complete  (8484.59s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.62279 observed at iteration 10
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.8105, 'metrics/recall(B)': 0.73017, 'metrics/mAP50(B)': 0.79883, 'metrics/mAP50-95(B)': 0.60323, 'val/box_loss': 0.63249, 'val/cls_loss': 0.8406, 'val/dfl_loss': 0.89444, 'fitness': 0.62279}
# Tuner: Best fitness model is runs\detect\train113
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01422
# momentum: 0.84031
# weight_decay: 0.00067
# warmup_epochs: 2.53384
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.44592
# dfl: 1.41531
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.85294
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 23/50 with hyperparameters: {'lr0': 0.01278, 'lrf': 0.01299, 'momentum': 0.81106, 'weight_decay': 0.00063, 'warmup_epochs': 2.19483, 'warmup_momentum': 0.95, 'box': 5.44002, 'cls': 0.48914, 'dfl': 1.45216, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09581, 'scale': 0.49715, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.8848, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 23/50 iterations complete  (8918.80s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.63372 observed at iteration 23
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.78921, 'metrics/recall(B)': 0.79393, 'metrics/mAP50(B)': 0.81254, 'metrics/mAP50-95(B)': 0.61386, 'val/box_loss': 0.60239, 'val/cls_loss': 0.87399, 'val/dfl_loss': 0.89319, 'fitness': 0.63372}
# Tuner: Best fitness model is runs\detect\train126
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01278
# lrf: 0.01299
# momentum: 0.81106
# weight_decay: 0.00063
# warmup_epochs: 2.19483
# warmup_momentum: 0.95
# box: 5.44002
# cls: 0.48914
# dfl: 1.45216
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09581
# scale: 0.49715
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.8848
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 24/50 with hyperparameters: {'lr0': 0.01182, 'lrf': 0.01813, 'momentum': 0.84031, 'weight_decay': 0.0006, 'warmup_epochs': 2.71073, 'warmup_momentum': 0.8692, 'box': 6.23486, 'cls': 0.61053, 'dfl': 1.72908, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09324, 'scale': 0.3064, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.65846, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 24/50 iterations complete  (9348.43s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.64335 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.84982, 'metrics/recall(B)': 0.76949, 'metrics/mAP50(B)': 0.8274, 'metrics/mAP50-95(B)': 0.6229, 'val/box_loss': 0.72691, 'val/cls_loss': 1.09239, 'val/dfl_loss': 1.08336, 'fitness': 0.64335}
# Tuner: Best fitness model is runs\detect\train127
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01813
# momentum: 0.84031
# weight_decay: 0.0006
# warmup_epochs: 2.71073
# warmup_momentum: 0.8692
# box: 6.23486
# cls: 0.61053
# dfl: 1.72908
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.3064
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.65846
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 25/50 with hyperparameters: {'lr0': 0.01182, 'lrf': 0.01472, 'momentum': 0.84411, 'weight_decay': 0.00063, 'warmup_epochs': 2.44004, 'warmup_momentum': 0.95, 'box': 4.91388, 'cls': 0.44592, 'dfl': 1.43678, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08835, 'scale': 0.48214, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.88932, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 25/50 iterations complete  (9779.17s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.64335 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.84982, 'metrics/recall(B)': 0.76949, 'metrics/mAP50(B)': 0.8274, 'metrics/mAP50-95(B)': 0.6229, 'val/box_loss': 0.72691, 'val/cls_loss': 1.09239, 'val/dfl_loss': 1.08336, 'fitness': 0.64335}
# Tuner: Best fitness model is runs\detect\train127
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01813
# momentum: 0.84031
# weight_decay: 0.0006
# warmup_epochs: 2.71073
# warmup_momentum: 0.8692
# box: 6.23486
# cls: 0.61053
# dfl: 1.72908
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.3064
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.65846
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 26/50 with hyperparameters: {'lr0': 0.01221, 'lrf': 0.01311, 'momentum': 0.82691, 'weight_decay': 0.00063, 'warmup_epochs': 1.92223, 'warmup_momentum': 0.90331, 'box': 5.44002, 'cls': 0.44938, 'dfl': 1.53618, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09284, 'scale': 0.4643, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.91927, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 26/50 iterations complete  (10213.09s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.64335 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.84982, 'metrics/recall(B)': 0.76949, 'metrics/mAP50(B)': 0.8274, 'metrics/mAP50-95(B)': 0.6229, 'val/box_loss': 0.72691, 'val/cls_loss': 1.09239, 'val/dfl_loss': 1.08336, 'fitness': 0.64335}
# Tuner: Best fitness model is runs\detect\train127
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01813
# momentum: 0.84031
# weight_decay: 0.0006
# warmup_epochs: 2.71073
# warmup_momentum: 0.8692
# box: 6.23486
# cls: 0.61053
# dfl: 1.72908
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.3064
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.65846
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 27/50 with hyperparameters: {'lr0': 0.01176, 'lrf': 0.01472, 'momentum': 0.84228, 'weight_decay': 0.00063, 'warmup_epochs': 2.44278, 'warmup_momentum': 0.95, 'box': 4.95179, 'cls': 0.44592, 'dfl': 1.43678, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08945, 'scale': 0.48385, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.89115, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 27/50 iterations complete  (10643.57s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.64335 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.84982, 'metrics/recall(B)': 0.76949, 'metrics/mAP50(B)': 0.8274, 'metrics/mAP50-95(B)': 0.6229, 'val/box_loss': 0.72691, 'val/cls_loss': 1.09239, 'val/dfl_loss': 1.08336, 'fitness': 0.64335}
# Tuner: Best fitness model is runs\detect\train127
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01813
# momentum: 0.84031
# weight_decay: 0.0006
# warmup_epochs: 2.71073
# warmup_momentum: 0.8692
# box: 6.23486
# cls: 0.61053
# dfl: 1.72908
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.3064
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.65846
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 28/50 with hyperparameters: {'lr0': 0.01271, 'lrf': 0.01336, 'momentum': 0.81106, 'weight_decay': 0.00064, 'warmup_epochs': 2.10727, 'warmup_momentum': 0.89666, 'box': 5.22728, 'cls': 0.49918, 'dfl': 1.4344, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09977, 'scale': 0.50512, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.88414, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 28/50 iterations complete  (11076.54s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.64335 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.84982, 'metrics/recall(B)': 0.76949, 'metrics/mAP50(B)': 0.8274, 'metrics/mAP50-95(B)': 0.6229, 'val/box_loss': 0.72691, 'val/cls_loss': 1.09239, 'val/dfl_loss': 1.08336, 'fitness': 0.64335}
# Tuner: Best fitness model is runs\detect\train127
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01813
# momentum: 0.84031
# weight_decay: 0.0006
# warmup_epochs: 2.71073
# warmup_momentum: 0.8692
# box: 6.23486
# cls: 0.61053
# dfl: 1.72908
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.3064
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.65846
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 29/50 with hyperparameters: {'lr0': 0.01231, 'lrf': 0.01332, 'momentum': 0.81446, 'weight_decay': 0.00059, 'warmup_epochs': 2.04586, 'warmup_momentum': 0.95, 'box': 5.42705, 'cls': 0.47269, 'dfl': 1.34394, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09006, 'scale': 0.49715, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.8848, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 29/50 iterations complete  (11509.57s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.64335 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.84982, 'metrics/recall(B)': 0.76949, 'metrics/mAP50(B)': 0.8274, 'metrics/mAP50-95(B)': 0.6229, 'val/box_loss': 0.72691, 'val/cls_loss': 1.09239, 'val/dfl_loss': 1.08336, 'fitness': 0.64335}
# Tuner: Best fitness model is runs\detect\train127
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01813
# momentum: 0.84031
# weight_decay: 0.0006
# warmup_epochs: 2.71073
# warmup_momentum: 0.8692
# box: 6.23486
# cls: 0.61053
# dfl: 1.72908
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.3064
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.65846
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 30/50 with hyperparameters: {'lr0': 0.01334, 'lrf': 0.01355, 'momentum': 0.79304, 'weight_decay': 0.00069, 'warmup_epochs': 2.19483, 'warmup_momentum': 0.90166, 'box': 5.44002, 'cls': 0.4444, 'dfl': 1.50763, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09661, 'scale': 0.46853, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.95815, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 30/50 iterations complete  (11943.16s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.64335 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.84982, 'metrics/recall(B)': 0.76949, 'metrics/mAP50(B)': 0.8274, 'metrics/mAP50-95(B)': 0.6229, 'val/box_loss': 0.72691, 'val/cls_loss': 1.09239, 'val/dfl_loss': 1.08336, 'fitness': 0.64335}
# Tuner: Best fitness model is runs\detect\train127
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01813
# momentum: 0.84031
# weight_decay: 0.0006
# warmup_epochs: 2.71073
# warmup_momentum: 0.8692
# box: 6.23486
# cls: 0.61053
# dfl: 1.72908
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.3064
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.65846
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 31/50 with hyperparameters: {'lr0': 0.01183, 'lrf': 0.01795, 'momentum': 0.84031, 'weight_decay': 0.0006, 'warmup_epochs': 2.71743, 'warmup_momentum': 0.87191, 'box': 6.27752, 'cls': 0.60725, 'dfl': 1.73976, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09521, 'scale': 0.30645, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.6623, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 31/50 iterations complete  (12232.41s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.64335 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.84982, 'metrics/recall(B)': 0.76949, 'metrics/mAP50(B)': 0.8274, 'metrics/mAP50-95(B)': 0.6229, 'val/box_loss': 0.72691, 'val/cls_loss': 1.09239, 'val/dfl_loss': 1.08336, 'fitness': 0.64335}
# Tuner: Best fitness model is runs\detect\train127
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01813
# momentum: 0.84031
# weight_decay: 0.0006
# warmup_epochs: 2.71073
# warmup_momentum: 0.8692
# box: 6.23486
# cls: 0.61053
# dfl: 1.72908
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.3064
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.65846
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 32/50 with hyperparameters: {'lr0': 0.01191, 'lrf': 0.01813, 'momentum': 0.84031, 'weight_decay': 0.00063, 'warmup_epochs': 2.71073, 'warmup_momentum': 0.95, 'box': 5.46998, 'cls': 0.67231, 'dfl': 2.40939, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10525, 'scale': 0.41661, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.66693, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 32/50 iterations complete  (12661.92s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.64335 observed at iteration 24
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.84982, 'metrics/recall(B)': 0.76949, 'metrics/mAP50(B)': 0.8274, 'metrics/mAP50-95(B)': 0.6229, 'val/box_loss': 0.72691, 'val/cls_loss': 1.09239, 'val/dfl_loss': 1.08336, 'fitness': 0.64335}
# Tuner: Best fitness model is runs\detect\train127
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01182
# lrf: 0.01813
# momentum: 0.84031
# weight_decay: 0.0006
# warmup_epochs: 2.71073
# warmup_momentum: 0.8692
# box: 6.23486
# cls: 0.61053
# dfl: 1.72908
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09324
# scale: 0.3064
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.65846
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 33/50 with hyperparameters: {'lr0': 0.01188, 'lrf': 0.01871, 'momentum': 0.84207, 'weight_decay': 0.00059, 'warmup_epochs': 3.05884, 'warmup_momentum': 0.92019, 'box': 6.23486, 'cls': 0.59226, 'dfl': 2.15191, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09878, 'scale': 0.29011, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.72494, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 33/50 iterations complete  (13089.26s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.65608 observed at iteration 33
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.83812, 'metrics/recall(B)': 0.73772, 'metrics/mAP50(B)': 0.81818, 'metrics/mAP50-95(B)': 0.63807, 'val/box_loss': 0.67535, 'val/cls_loss': 1.06438, 'val/dfl_loss': 1.32275, 'fitness': 0.65608}
# Tuner: Best fitness model is runs\detect\train136
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01188
# lrf: 0.01871
# momentum: 0.84207
# weight_decay: 0.00059
# warmup_epochs: 3.05884
# warmup_momentum: 0.92019
# box: 6.23486
# cls: 0.59226
# dfl: 2.15191
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09878
# scale: 0.29011
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.72494
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 34/50 with hyperparameters: {'lr0': 0.01236, 'lrf': 0.01808, 'momentum': 0.84436, 'weight_decay': 0.00058, 'warmup_epochs': 3.16855, 'warmup_momentum': 0.95, 'box': 6.26911, 'cls': 0.59972, 'dfl': 2.15191, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.10146, 'scale': 0.28741, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.72718, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 34/50 iterations complete  (13516.91s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.65608 observed at iteration 33
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.83812, 'metrics/recall(B)': 0.73772, 'metrics/mAP50(B)': 0.81818, 'metrics/mAP50-95(B)': 0.63807, 'val/box_loss': 0.67535, 'val/cls_loss': 1.06438, 'val/dfl_loss': 1.32275, 'fitness': 0.65608}
# Tuner: Best fitness model is runs\detect\train136
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01188
# lrf: 0.01871
# momentum: 0.84207
# weight_decay: 0.00059
# warmup_epochs: 3.05884
# ...
#
# lr0: 0.01188
# lrf: 0.02143
# momentum: 0.86268
# weight_decay: 0.00068
# warmup_epochs: 2.72098
# warmup_momentum: 0.85453
# box: 7.16283
# cls: 0.66295
# dfl: 2.15191
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1161
# scale: 0.29134
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69299
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 40/50 with hyperparameters: {'lr0': 0.01225, 'lrf': 0.01718, 'momentum': 0.84389, 'weight_decay': 0.00056, 'warmup_epochs': 3.39639, 'warmup_momentum': 0.94837, 'box': 5.52717, 'cls': 0.59239, 'dfl': 2.0901, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09983, 'scale': 0.25435, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.72658, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 40/50 iterations complete  (15476.64s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.65964 observed at iteration 39
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.80975, 'metrics/recall(B)': 0.79011, 'metrics/mAP50(B)': 0.82267, 'metrics/mAP50-95(B)': 0.64153, 'val/box_loss': 0.79569, 'val/cls_loss': 1.18199, 'val/dfl_loss': 1.33871, 'fitness': 0.65964}
# Tuner: Best fitness model is runs\detect\train142
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01188
# lrf: 0.02143
# momentum: 0.86268
# weight_decay: 0.00068
# warmup_epochs: 2.72098
# warmup_momentum: 0.85453
# box: 7.16283
# cls: 0.66295
# dfl: 2.15191
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1161
# scale: 0.29134
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69299
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 41/50 with hyperparameters: {'lr0': 0.01148, 'lrf': 0.02104, 'momentum': 0.87525, 'weight_decay': 0.00068, 'warmup_epochs': 2.75156, 'warmup_momentum': 0.82757, 'box': 7.51171, 'cls': 0.69976, 'dfl': 2.22335, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.11628, 'scale': 0.29669, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.69299, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 41/50 iterations complete  (15902.94s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.65964 observed at iteration 39
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.80975, 'metrics/recall(B)': 0.79011, 'metrics/mAP50(B)': 0.82267, 'metrics/mAP50-95(B)': 0.64153, 'val/box_loss': 0.79569, 'val/cls_loss': 1.18199, 'val/dfl_loss': 1.33871, 'fitness': 0.65964}
# Tuner: Best fitness model is runs\detect\train142
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01188
# lrf: 0.02143
# momentum: 0.86268
# weight_decay: 0.00068
# warmup_epochs: 2.72098
# warmup_momentum: 0.85453
# box: 7.16283
# cls: 0.66295
# dfl: 2.15191
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1161
# scale: 0.29134
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69299
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 42/50 with hyperparameters: {'lr0': 0.01158, 'lrf': 0.02143, 'momentum': 0.89424, 'weight_decay': 0.00064, 'warmup_epochs': 2.72098, 'warmup_momentum': 0.83889, 'box': 6.68647, 'cls': 0.75483, 'dfl': 1.99848, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.11726, 'scale': 0.29521, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.69398, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 42/50 iterations complete  (16331.36s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.66159 observed at iteration 42
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.85691, 'metrics/recall(B)': 0.77069, 'metrics/mAP50(B)': 0.83693, 'metrics/mAP50-95(B)': 0.64211, 'val/box_loss': 0.74758, 'val/cls_loss': 1.34479, 'val/dfl_loss': 1.23085, 'fitness': 0.66159}
# Tuner: Best fitness model is runs\detect\train145
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01158
# lrf: 0.02143
# momentum: 0.89424
# weight_decay: 0.00064
# warmup_epochs: 2.72098
# warmup_momentum: 0.83889
# box: 6.68647
# cls: 0.75483
# dfl: 1.99848
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.11726
# scale: 0.29521
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69398
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 43/50 with hyperparameters: {'lr0': 0.01193, 'lrf': 0.01727, 'momentum': 0.84436, 'weight_decay': 0.00058, 'warmup_epochs': 3.65374, 'warmup_momentum': 0.9357, 'box': 6.26911, 'cls': 0.5158, 'dfl': 2.0868, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09279, 'scale': 0.32649, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.72718, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 43/50 iterations complete  (16759.32s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.66159 observed at iteration 42
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.85691, 'metrics/recall(B)': 0.77069, 'metrics/mAP50(B)': 0.83693, 'metrics/mAP50-95(B)': 0.64211, 'val/box_loss': 0.74758, 'val/cls_loss': 1.34479, 'val/dfl_loss': 1.23085, 'fitness': 0.66159}
# Tuner: Best fitness model is runs\detect\train145
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01158
# lrf: 0.02143
# momentum: 0.89424
# weight_decay: 0.00064
# warmup_epochs: 2.72098
# warmup_momentum: 0.83889
# box: 6.68647
# cls: 0.75483
# dfl: 1.99848
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.11726
# scale: 0.29521
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69398
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 44/50 with hyperparameters: {'lr0': 0.01207, 'lrf': 0.02129, 'momentum': 0.85502, 'weight_decay': 0.00068, 'warmup_epochs': 2.73696, 'warmup_momentum': 0.85453, 'box': 6.63838, 'cls': 0.67032, 'dfl': 2.15191, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.12248, 'scale': 0.27361, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.7162, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 44/50 iterations complete  (16952.55s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.66159 observed at iteration 42
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.85691, 'metrics/recall(B)': 0.77069, 'metrics/mAP50(B)': 0.83693, 'metrics/mAP50-95(B)': 0.64211, 'val/box_loss': 0.74758, 'val/cls_loss': 1.34479, 'val/dfl_loss': 1.23085, 'fitness': 0.66159}
# Tuner: Best fitness model is runs\detect\train145
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01158
# lrf: 0.02143
# momentum: 0.89424
# weight_decay: 0.00064
# warmup_epochs: 2.72098
# warmup_momentum: 0.83889
# box: 6.68647
# cls: 0.75483
# dfl: 1.99848
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.11726
# scale: 0.29521
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69398
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 45/50 with hyperparameters: {'lr0': 0.01014, 'lrf': 0.02006, 'momentum': 0.89444, 'weight_decay': 0.0006, 'warmup_epochs': 2.51594, 'warmup_momentum': 0.74815, 'box': 8.09268, 'cls': 0.74763, 'dfl': 1.99848, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.1302, 'scale': 0.2866, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.65009, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 45/50 iterations complete  (17378.29s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.66159 observed at iteration 42
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.85691, 'metrics/recall(B)': 0.77069, 'metrics/mAP50(B)': 0.83693, 'metrics/mAP50-95(B)': 0.64211, 'val/box_loss': 0.74758, 'val/cls_loss': 1.34479, 'val/dfl_loss': 1.23085, 'fitness': 0.66159}
# Tuner: Best fitness model is runs\detect\train145
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01158
# lrf: 0.02143
# momentum: 0.89424
# weight_decay: 0.00064
# warmup_epochs: 2.72098
# warmup_momentum: 0.83889
# box: 6.68647
# cls: 0.75483
# dfl: 1.99848
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.11726
# scale: 0.29521
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69398
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 46/50 with hyperparameters: {'lr0': 0.01168, 'lrf': 0.02143, 'momentum': 0.88111, 'weight_decay': 0.00064, 'warmup_epochs': 2.58052, 'warmup_momentum': 0.83273, 'box': 5.50592, 'cls': 0.8234, 'dfl': 2.13885, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.11359, 'scale': 0.29963, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.73572, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 46/50 iterations complete  (17480.52s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.66159 observed at iteration 42
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.85691, 'metrics/recall(B)': 0.77069, 'metrics/mAP50(B)': 0.83693, 'metrics/mAP50-95(B)': 0.64211, 'val/box_loss': 0.74758, 'val/cls_loss': 1.34479, 'val/dfl_loss': 1.23085, 'fitness': 0.66159}
# Tuner: Best fitness model is runs\detect\train145
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01158
# lrf: 0.02143
# momentum: 0.89424
# weight_decay: 0.00064
# warmup_epochs: 2.72098
# warmup_momentum: 0.83889
# box: 6.68647
# cls: 0.75483
# dfl: 1.99848
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.11726
# scale: 0.29521
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69398
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 47/50 with hyperparameters: {'lr0': 0.01199, 'lrf': 0.01869, 'momentum': 0.84207, 'weight_decay': 0.00059, 'warmup_epochs': 3.05884, 'warmup_momentum': 0.92483, 'box': 6.22914, 'cls': 0.58668, 'dfl': 2.17502, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09878, 'scale': 0.29052, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.72423, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 47/50 iterations complete  (17907.59s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.66159 observed at iteration 42
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.85691, 'metrics/recall(B)': 0.77069, 'metrics/mAP50(B)': 0.83693, 'metrics/mAP50-95(B)': 0.64211, 'val/box_loss': 0.74758, 'val/cls_loss': 1.34479, 'val/dfl_loss': 1.23085, 'fitness': 0.66159}
# Tuner: Best fitness model is runs\detect\train145
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01158
# lrf: 0.02143
# momentum: 0.89424
# weight_decay: 0.00064
# warmup_epochs: 2.72098
# warmup_momentum: 0.83889
# box: 6.68647
# cls: 0.75483
# dfl: 1.99848
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.11726
# scale: 0.29521
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69398
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 48/50 with hyperparameters: {'lr0': 0.01284, 'lrf': 0.01805, 'momentum': 0.80879, 'weight_decay': 0.00062, 'warmup_epochs': 3.05884, 'warmup_momentum': 0.92019, 'box': 7.13211, 'cls': 0.55861, 'dfl': 2.14694, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09562, 'scale': 0.29011, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.75658, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 48/50 iterations complete  (18336.05s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.66159 observed at iteration 42
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.85691, 'metrics/recall(B)': 0.77069, 'metrics/mAP50(B)': 0.83693, 'metrics/mAP50-95(B)': 0.64211, 'val/box_loss': 0.74758, 'val/cls_loss': 1.34479, 'val/dfl_loss': 1.23085, 'fitness': 0.66159}
# Tuner: Best fitness model is runs\detect\train145
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01158
# lrf: 0.02143
# momentum: 0.89424
# weight_decay: 0.00064
# warmup_epochs: 2.72098
# warmup_momentum: 0.83889
# box: 6.68647
# cls: 0.75483
# dfl: 1.99848
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.11726
# scale: 0.29521
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69398
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 49/50 with hyperparameters: {'lr0': 0.01158, 'lrf': 0.02104, 'momentum': 0.94823, 'weight_decay': 0.00068, 'warmup_epochs': 2.72158, 'warmup_momentum': 0.86902, 'box': 8.1692, 'cls': 0.75893, 'dfl': 1.99848, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.11176, 'scale': 0.31069, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.85554, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 49/50 iterations complete  (18767.88s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.66159 observed at iteration 42
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.85691, 'metrics/recall(B)': 0.77069, 'metrics/mAP50(B)': 0.83693, 'metrics/mAP50-95(B)': 0.64211, 'val/box_loss': 0.74758, 'val/cls_loss': 1.34479, 'val/dfl_loss': 1.23085, 'fitness': 0.66159}
# Tuner: Best fitness model is runs\detect\train145
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01158
# lrf: 0.02143
# momentum: 0.89424
# weight_decay: 0.00064
# warmup_epochs: 2.72098
# warmup_momentum: 0.83889
# box: 6.68647
# cls: 0.75483
# dfl: 1.99848
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.11726
# scale: 0.29521
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69398
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 50/50 with hyperparameters: {'lr0': 0.01162, 'lrf': 0.01843, 'momentum': 0.84458, 'weight_decay': 0.00059, 'warmup_epochs': 3.12761, 'warmup_momentum': 0.9115, 'box': 6.23917, 'cls': 0.601, 'dfl': 2.12777, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09878, 'scale': 0.29682, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.0, 'mosaic': 0.70049, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune10\tune_scatter_plots.png
# Saved runs\detect\tune10\tune_fitness.png
#
# Tuner: 50/50 iterations complete  (19195.91s)
# Tuner: Results saved to runs\detect\tune10
# Tuner: Best fitness=0.66159 observed at iteration 42
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.85691, 'metrics/recall(B)': 0.77069, 'metrics/mAP50(B)': 0.83693, 'metrics/mAP50-95(B)': 0.64211, 'val/box_loss': 0.74758, 'val/cls_loss': 1.34479, 'val/dfl_loss': 1.23085, 'fitness': 0.66159}
# Tuner: Best fitness model is runs\detect\train145
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune10\best_hyperparameters.yaml'
#
# lr0: 0.01158
# lrf: 0.02143
# momentum: 0.89424
# weight_decay: 0.00064
# warmup_epochs: 2.72098
# warmup_momentum: 0.83889
# box: 6.68647
# cls: 0.75483
# dfl: 1.99848
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.11726
# scale: 0.29521
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.0
# mosaic: 0.69398
# mixup: 0.0
# copy_paste: 0.0
