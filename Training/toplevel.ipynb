# %% [markdown]
# # TOP LEVEL TRAINING

# %% [markdown]
# ### CONFIG VARS

# %%
from utils import *
from ultralytics import YOLO

# %%
DATASET_PATH="../Datasets/Dataset_TopLevel"
PREPROCESSED_PATH="../Preprocessed_Datasets/TopLevel"
AUGMENTED_PATH="../Augmented_Datasets/TopLevel"
AUGMENTED_PATH_TRAIN_EX="../Augmented_Datasets/TopLevel_train" # Data exclusively for training, not validating
YOLO_PATH="../YOLO_Datasets/TopLevel"
YOLO_PATH_TRAIN_EX="../YOLO_Datasets/TopLevel_train" # Data exclusively for training, not validating

# %%
if not os.path.exists(AUGMENTED_PATH):
    os.makedirs(AUGMENTED_PATH)
if not os.path.exists(AUGMENTED_PATH_TRAIN_EX):
    os.makedirs(AUGMENTED_PATH_TRAIN_EX)

# %% [markdown]
# ### AUGMENTATION

# %% [markdown]
# For this model we will apply the following augmentation techniques:
# - Hue transformations (-100º to +100º)
# - Contrast inversion (To simulate dark and light modes)

# %%
resize_dataset_images(DATASET_PATH, AUGMENTED_PATH, 640, 360)

# %%
hue_augmentation(AUGMENTED_PATH, AUGMENTED_PATH_TRAIN_EX, 0.15, 100)

# %%
contrast_inversion_augmentation(AUGMENTED_PATH, AUGMENTED_PATH_TRAIN_EX, 0.15)

# %%
# Add the augmented data to the train exclusively folder
for file in os.listdir(AUGMENTED_PATH):
    shutil.copy(os.path.join(AUGMENTED_PATH, file), AUGMENTED_PATH_TRAIN_EX)

# %% [markdown]
# ### FORMAT CONVERSION
#
# Up to now, we have treated with labelme format datasets, but we need to convert it to YOLOv8 format if we want to train
# a model, which has the following format:
#
# ```
# YOLOv8_Dataset/
# ├── data.yaml
# ├── train/
# │   ├── images/
# │   │   ├── img1.jpg
# │   │   ├── img2.jpg
# │   │   └── ...
# │   ├── labels/
# │   │   ├── img1.txt
# │   │   ├── img2.txt
# │   │   └── ...
# ├── valid/
# │   ├── images/
# │   │   ├── img1.jpg
# │   │   ├── img2.jpg
# │   │   └── ...
# │   ├── labels/
# │   │   ├── img1.txt
# │   │   ├── img2.txt
# │   │   └── ...
# └── test/ (OPTIONAL)
#     ├── images/
#     │   ├── img1.jpg
#     │   ├── img2.jpg
#     │   └── ...
#     └── labels/
#         ├── img1.txt
#         ├── img2.txt
#         └── ...
# ```
#
# The format of the data.yml file is:
# ```
# path: <path_to_dataset_root_dit>
# train: <path_to_train_images>
# val: <path_to_validation_images>
# test: <path_to_test_images> (OPTIONAL)
#
# nc: <number_of_classes>
# names: ['class1', 'class2', 'class3', ...]
# ```
#
# The labels for Instance segmentation have the following format for each annotation:
# ```
# <class-index> <x1> <y1> <x2> <y2> ... <xn> <yn>
# ```

# %%
labelme_to_yolo(AUGMENTED_PATH_TRAIN_EX, YOLO_PATH_TRAIN_EX, 0.7,[
                    "Application",
                    "Taskbar",
                    "Dock"
                ], "seg")

# %% [markdown]
# ### TRAIN

# %% [markdown]
# We will perform fine-tuning over the mobile-sam model using the hyperparameter tuning provided by Ultralytics to get the
# best results we can. Since this is a non-standard dataset in terms of object features it is not clear what are the values
# we should use.
#
# We will also configure the training to not do any augmentation over the train set

# %%
from ultralytics import YOLO
# Initialize the YOLO model
model = YOLO("yolov8s-seg")

# %%
import torch
# check if CUDA is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using {} device'.format(device))
# Out:
# Using cuda device

# %%
# Tune hyperparameters on dataset for 30 epochs
model.tune(data=f"{YOLO_PATH_TRAIN_EX}/data.yaml", workers=1, iterations=20, epochs=30, optimizer='AdamW', plots=False, save=True, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs\segment\tune15'
# Tuner:  Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/20 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 1/20 iterations complete  (4451.73s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.28158 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.87908, 'metrics/recall(B)': 0.22464, 'metrics/mAP50(B)': 0.24491, 'metrics/mAP50-95(B)': 0.14919, 'metrics/precision(M)': 0.86071, 'metrics/recall(M)': 0.21014, 'metrics/mAP50(M)': 0.21727, 'metrics/mAP50-95(M)': 0.11233, 'val/box_loss': 1.65553, 'val/seg_loss': 1.38603, 'val/cls_loss': 2.04385, 'val/dfl_loss': 1.18473, 'fitness': 0.28158}
# Tuner: Best fitness model is runs\segment\train119
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 2/20 with hyperparameters: {'lr0': 0.01026, 'lrf': 0.00986, 'momentum': 0.94443, 'weight_decay': 0.0005, 'warmup_epochs': 3.01609, 'warmup_momentum': 0.80694, 'box': 7.70941, 'cls': 0.49847, 'dfl': 1.50708, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09838, 'scale': 0.48858, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 2/20 iterations complete  (7475.52s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.31686 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.62338, 'metrics/recall(B)': 0.3341, 'metrics/mAP50(B)': 0.28168, 'metrics/mAP50-95(B)': 0.15205, 'metrics/precision(M)': 0.60113, 'metrics/recall(M)': 0.3196, 'metrics/mAP50(M)': 0.26439, 'metrics/mAP50-95(M)': 0.13935, 'val/box_loss': 1.86789, 'val/seg_loss': 2.37627, 'val/cls_loss': 2.05042, 'val/dfl_loss': 1.3964, 'fitness': 0.31686}
# Tuner: Best fitness model is runs\segment\train120
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.01026
# lrf: 0.00986
# momentum: 0.94443
# weight_decay: 0.0005
# warmup_epochs: 3.01609
# warmup_momentum: 0.80694
# box: 7.70941
# cls: 0.49847
# dfl: 1.50708
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09838
# scale: 0.48858
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 3/20 with hyperparameters: {'lr0': 0.01197, 'lrf': 0.01125, 'momentum': 0.94825, 'weight_decay': 0.00052, 'warmup_epochs': 3.01609, 'warmup_momentum': 0.80694, 'box': 7.70941, 'cls': 0.59551, 'dfl': 1.46095, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09772, 'scale': 0.52681, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.44762, 'mosaic': 0.92367, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 3/20 iterations complete  (10020.21s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.31686 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.62338, 'metrics/recall(B)': 0.3341, 'metrics/mAP50(B)': 0.28168, 'metrics/mAP50-95(B)': 0.15205, 'metrics/precision(M)': 0.60113, 'metrics/recall(M)': 0.3196, 'metrics/mAP50(M)': 0.26439, 'metrics/mAP50-95(M)': 0.13935, 'val/box_loss': 1.86789, 'val/seg_loss': 2.37627, 'val/cls_loss': 2.05042, 'val/dfl_loss': 1.3964, 'fitness': 0.31686}
# Tuner: Best fitness model is runs\segment\train120
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.01026
# lrf: 0.00986
# momentum: 0.94443
# weight_decay: 0.0005
# warmup_epochs: 3.01609
# warmup_momentum: 0.80694
# box: 7.70941
# cls: 0.49847
# dfl: 1.50708
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09838
# scale: 0.48858
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 4/20 with hyperparameters: {'lr0': 0.01011, 'lrf': 0.01019, 'momentum': 0.95341, 'weight_decay': 0.00047, 'warmup_epochs': 3.21457, 'warmup_momentum': 0.84666, 'box': 7.66848, 'cls': 0.57817, 'dfl': 1.49962, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09838, 'scale': 0.45172, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.47734, 'mosaic': 0.91525, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 4/20 iterations complete  (12163.36s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.31686 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.62338, 'metrics/recall(B)': 0.3341, 'metrics/mAP50(B)': 0.28168, 'metrics/mAP50-95(B)': 0.15205, 'metrics/precision(M)': 0.60113, 'metrics/recall(M)': 0.3196, 'metrics/mAP50(M)': 0.26439, 'metrics/mAP50-95(M)': 0.13935, 'val/box_loss': 1.86789, 'val/seg_loss': 2.37627, 'val/cls_loss': 2.05042, 'val/dfl_loss': 1.3964, 'fitness': 0.31686}
# Tuner: Best fitness model is runs\segment\train120
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.01026
# lrf: 0.00986
# momentum: 0.94443
# weight_decay: 0.0005
# warmup_epochs: 3.01609
# warmup_momentum: 0.80694
# box: 7.70941
# cls: 0.49847
# dfl: 1.50708
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09838
# scale: 0.48858
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 5/20 with hyperparameters: {'lr0': 0.0107, 'lrf': 0.01125, 'momentum': 0.95341, 'weight_decay': 0.00041, 'warmup_epochs': 3.111, 'warmup_momentum': 0.82947, 'box': 7.92603, 'cls': 0.51351, 'dfl': 1.4429, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.09601, 'scale': 0.42172, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.47734, 'mosaic': 0.9041, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 5/20 iterations complete  (13463.57s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.37724 observed at iteration 5
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.70223, 'metrics/recall(B)': 0.36575, 'metrics/mAP50(B)': 0.35945, 'metrics/mAP50-95(B)': 0.18163, 'metrics/precision(M)': 0.70721, 'metrics/recall(M)': 0.33004, 'metrics/mAP50(M)': 0.30891, 'metrics/mAP50-95(M)': 0.16326, 'val/box_loss': 1.94889, 'val/seg_loss': 1.81356, 'val/cls_loss': 2.361, 'val/dfl_loss': 1.4013, 'fitness': 0.37724}
# Tuner: Best fitness model is runs\segment\train123
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.0107
# lrf: 0.01125
# momentum: 0.95341
# weight_decay: 0.00041
# warmup_epochs: 3.111
# warmup_momentum: 0.82947
# box: 7.92603
# cls: 0.51351
# dfl: 1.4429
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09601
# scale: 0.42172
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.47734
# mosaic: 0.9041
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 6/20 with hyperparameters: {'lr0': 0.01007, 'lrf': 0.00903, 'momentum': 0.90894, 'weight_decay': 0.00051, 'warmup_epochs': 2.50671, 'warmup_momentum': 0.76089, 'box': 7.44911, 'cls': 0.43159, 'dfl': 1.59784, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.07899, 'scale': 0.48864, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 6/20 iterations complete  (14776.96s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.37724 observed at iteration 5
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.70223, 'metrics/recall(B)': 0.36575, 'metrics/mAP50(B)': 0.35945, 'metrics/mAP50-95(B)': 0.18163, 'metrics/precision(M)': 0.70721, 'metrics/recall(M)': 0.33004, 'metrics/mAP50(M)': 0.30891, 'metrics/mAP50-95(M)': 0.16326, 'val/box_loss': 1.94889, 'val/seg_loss': 1.81356, 'val/cls_loss': 2.361, 'val/dfl_loss': 1.4013, 'fitness': 0.37724}
# Tuner: Best fitness model is runs\segment\train123
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.0107
# lrf: 0.01125
# momentum: 0.95341
# weight_decay: 0.00041
# warmup_epochs: 3.111
# warmup_momentum: 0.82947
# box: 7.92603
# cls: 0.51351
# dfl: 1.4429
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.09601
# scale: 0.42172
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.47734
# mosaic: 0.9041
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 7/20 with hyperparameters: {'lr0': 0.01088, 'lrf': 0.0101, 'momentum': 0.93815, 'weight_decay': 0.00046, 'warmup_epochs': 3.30864, 'warmup_momentum': 0.80373, 'box': 7.3988, 'cls': 0.46475, 'dfl': 1.75291, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08481, 'scale': 0.49428, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.48373, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 7/20 iterations complete  (16074.56s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.42404 observed at iteration 7
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.63385, 'metrics/recall(B)': 0.41336, 'metrics/mAP50(B)': 0.35232, 'metrics/mAP50-95(B)': 0.21839, 'metrics/precision(M)': 0.61237, 'metrics/recall(M)': 0.37643, 'metrics/mAP50(M)': 0.3216, 'metrics/mAP50-95(M)': 0.17789, 'val/box_loss': 1.51197, 'val/seg_loss': 1.51491, 'val/cls_loss': 1.41398, 'val/dfl_loss': 1.37589, 'fitness': 0.42404}
# Tuner: Best fitness model is runs\segment\train125
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.01088
# lrf: 0.0101
# momentum: 0.93815
# weight_decay: 0.00046
# warmup_epochs: 3.30864
# warmup_momentum: 0.80373
# box: 7.3988
# cls: 0.46475
# dfl: 1.75291
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.08481
# scale: 0.49428
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.48373
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 8/20 with hyperparameters: {'lr0': 0.01173, 'lrf': 0.0101, 'momentum': 0.88524, 'weight_decay': 0.00044, 'warmup_epochs': 3.30864, 'warmup_momentum': 0.80373, 'box': 7.9775, 'cls': 0.32997, 'dfl': 1.75291, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.07306, 'scale': 0.49537, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.48373, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 8/20 iterations complete  (17382.38s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.46279 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.6823, 'metrics/recall(B)': 0.38368, 'metrics/mAP50(B)': 0.38836, 'metrics/mAP50-95(B)': 0.23246, 'metrics/precision(M)': 0.68029, 'metrics/recall(M)': 0.36918, 'metrics/mAP50(M)': 0.35945, 'metrics/mAP50-95(M)': 0.19865, 'val/box_loss': 1.67164, 'val/seg_loss': 1.25439, 'val/cls_loss': 1.00323, 'val/dfl_loss': 1.33148, 'fitness': 0.46279}
# Tuner: Best fitness model is runs\segment\train126
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.01173
# lrf: 0.0101
# momentum: 0.88524
# weight_decay: 0.00044
# warmup_epochs: 3.30864
# warmup_momentum: 0.80373
# box: 7.9775
# cls: 0.32997
# dfl: 1.75291
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07306
# scale: 0.49537
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.48373
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 9/20 with hyperparameters: {'lr0': 0.01075, 'lrf': 0.01291, 'momentum': 0.92454, 'weight_decay': 0.00039, 'warmup_epochs': 1.93981, 'warmup_momentum': 0.80373, 'box': 7.9775, 'cls': 0.3042, 'dfl': 1.75291, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.06465, 'scale': 0.39087, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.23648, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 9/20 iterations complete  (18727.09s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.46279 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.6823, 'metrics/recall(B)': 0.38368, 'metrics/mAP50(B)': 0.38836, 'metrics/mAP50-95(B)': 0.23246, 'metrics/precision(M)': 0.68029, 'metrics/recall(M)': 0.36918, 'metrics/mAP50(M)': 0.35945, 'metrics/mAP50-95(M)': 0.19865, 'val/box_loss': 1.67164, 'val/seg_loss': 1.25439, 'val/cls_loss': 1.00323, 'val/dfl_loss': 1.33148, 'fitness': 0.46279}
# Tuner: Best fitness model is runs\segment\train126
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.01173
# lrf: 0.0101
# momentum: 0.88524
# weight_decay: 0.00044
# warmup_epochs: 3.30864
# warmup_momentum: 0.80373
# box: 7.9775
# cls: 0.32997
# dfl: 1.75291
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07306
# scale: 0.49537
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.48373
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 10/20 with hyperparameters: {'lr0': 0.01087, 'lrf': 0.01013, 'momentum': 0.93747, 'weight_decay': 0.00046, 'warmup_epochs': 3.30773, 'warmup_momentum': 0.80579, 'box': 7.35764, 'cls': 0.4642, 'dfl': 1.74953, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08541, 'scale': 0.49191, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.48921, 'mosaic': 0.99935, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 10/20 iterations complete  (20015.26s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.46279 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.6823, 'metrics/recall(B)': 0.38368, 'metrics/mAP50(B)': 0.38836, 'metrics/mAP50-95(B)': 0.23246, 'metrics/precision(M)': 0.68029, 'metrics/recall(M)': 0.36918, 'metrics/mAP50(M)': 0.35945, 'metrics/mAP50-95(M)': 0.19865, 'val/box_loss': 1.67164, 'val/seg_loss': 1.25439, 'val/cls_loss': 1.00323, 'val/dfl_loss': 1.33148, 'fitness': 0.46279}
# Tuner: Best fitness model is runs\segment\train126
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.01173
# lrf: 0.0101
# momentum: 0.88524
# weight_decay: 0.00044
# warmup_epochs: 3.30864
# warmup_momentum: 0.80373
# box: 7.9775
# cls: 0.32997
# dfl: 1.75291
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07306
# scale: 0.49537
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.48373
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 11/20 with hyperparameters: {'lr0': 0.0121, 'lrf': 0.01104, 'momentum': 0.86742, 'weight_decay': 0.0004, 'warmup_epochs': 3.30864, 'warmup_momentum': 0.76577, 'box': 8.77174, 'cls': 0.32677, 'dfl': 1.57974, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.07306, 'scale': 0.49188, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.44153, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 11/20 iterations complete  (21313.91s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.46279 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.6823, 'metrics/recall(B)': 0.38368, 'metrics/mAP50(B)': 0.38836, 'metrics/mAP50-95(B)': 0.23246, 'metrics/precision(M)': 0.68029, 'metrics/recall(M)': 0.36918, 'metrics/mAP50(M)': 0.35945, 'metrics/mAP50-95(M)': 0.19865, 'val/box_loss': 1.67164, 'val/seg_loss': 1.25439, 'val/cls_loss': 1.00323, 'val/dfl_loss': 1.33148, 'fitness': 0.46279}
# Tuner: Best fitness model is runs\segment\train126
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.01173
# lrf: 0.0101
# momentum: 0.88524
# weight_decay: 0.00044
# warmup_epochs: 3.30864
# warmup_momentum: 0.80373
# box: 7.9775
# cls: 0.32997
# dfl: 1.75291
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07306
# scale: 0.49537
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.48373
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 12/20 with hyperparameters: {'lr0': 0.0108, 'lrf': 0.01364, 'momentum': 0.98, 'weight_decay': 0.00027, 'warmup_epochs': 1.93981, 'warmup_momentum': 0.7631, 'box': 7.9775, 'cls': 0.3042, 'dfl': 1.75419, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.06087, 'scale': 0.39897, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.23648, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 12/20 iterations complete  (22622.75s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.46279 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.6823, 'metrics/recall(B)': 0.38368, 'metrics/mAP50(B)': 0.38836, 'metrics/mAP50-95(B)': 0.23246, 'metrics/precision(M)': 0.68029, 'metrics/recall(M)': 0.36918, 'metrics/mAP50(M)': 0.35945, 'metrics/mAP50-95(M)': 0.19865, 'val/box_loss': 1.67164, 'val/seg_loss': 1.25439, 'val/cls_loss': 1.00323, 'val/dfl_loss': 1.33148, 'fitness': 0.46279}
# Tuner: Best fitness model is runs\segment\train126
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.01173
# lrf: 0.0101
# momentum: 0.88524
# weight_decay: 0.00044
# warmup_epochs: 3.30864
# warmup_momentum: 0.80373
# box: 7.9775
# cls: 0.32997
# dfl: 1.75291
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07306
# scale: 0.49537
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.48373
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 13/20 with hyperparameters: {'lr0': 0.01075, 'lrf': 0.01243, 'momentum': 0.91982, 'weight_decay': 0.00041, 'warmup_epochs': 1.91407, 'warmup_momentum': 0.79175, 'box': 8.03111, 'cls': 0.33889, 'dfl': 1.8309, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.06684, 'scale': 0.38684, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.26221, 'mosaic': 0.96116, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 13/20 iterations complete  (23919.38s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.46279 observed at iteration 8
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.6823, 'metrics/recall(B)': 0.38368, 'metrics/mAP50(B)': 0.38836, 'metrics/mAP50-95(B)': 0.23246, 'metrics/precision(M)': 0.68029, 'metrics/recall(M)': 0.36918, 'metrics/mAP50(M)': 0.35945, 'metrics/mAP50-95(M)': 0.19865, 'val/box_loss': 1.67164, 'val/seg_loss': 1.25439, 'val/cls_loss': 1.00323, 'val/dfl_loss': 1.33148, 'fitness': 0.46279}
# Tuner: Best fitness model is runs\segment\train126
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.01173
# lrf: 0.0101
# momentum: 0.88524
# weight_decay: 0.00044
# warmup_epochs: 3.30864
# warmup_momentum: 0.80373
# box: 7.9775
# cls: 0.32997
# dfl: 1.75291
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07306
# scale: 0.49537
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.48373
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 14/20 with hyperparameters: {'lr0': 0.0076, 'lrf': 0.01098, 'momentum': 0.91641, 'weight_decay': 0.00043, 'warmup_epochs': 1.91407, 'warmup_momentum': 0.84567, 'box': 8.03111, 'cls': 0.28108, 'dfl': 1.61628, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.07192, 'scale': 0.32029, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.26221, 'mosaic': 0.848, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 14/20 iterations complete  (25207.11s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.60689 observed at iteration 14
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.80262, 'metrics/recall(B)': 0.42296, 'metrics/mAP50(B)': 0.48825, 'metrics/mAP50-95(B)': 0.30346, 'metrics/precision(M)': 0.77848, 'metrics/recall(M)': 0.39397, 'metrics/mAP50(M)': 0.45219, 'metrics/mAP50-95(M)': 0.26637, 'val/box_loss': 1.38808, 'val/seg_loss': 1.44468, 'val/cls_loss': 0.67167, 'val/dfl_loss': 1.05757, 'fitness': 0.60689}
# Tuner: Best fitness model is runs\segment\train132
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.0076
# lrf: 0.01098
# momentum: 0.91641
# weight_decay: 0.00043
# warmup_epochs: 1.91407
# warmup_momentum: 0.84567
# box: 8.03111
# cls: 0.28108
# dfl: 1.61628
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07192
# scale: 0.32029
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.26221
# mosaic: 0.848
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 15/20 with hyperparameters: {'lr0': 0.00964, 'lrf': 0.0091, 'momentum': 0.91468, 'weight_decay': 0.00045, 'warmup_epochs': 1.95308, 'warmup_momentum': 0.92035, 'box': 6.57045, 'cls': 0.24907, 'dfl': 1.5107, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.069, 'scale': 0.29921, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.26221, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 15/20 iterations complete  (26517.68s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.60689 observed at iteration 14
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.80262, 'metrics/recall(B)': 0.42296, 'metrics/mAP50(B)': 0.48825, 'metrics/mAP50-95(B)': 0.30346, 'metrics/precision(M)': 0.77848, 'metrics/recall(M)': 0.39397, 'metrics/mAP50(M)': 0.45219, 'metrics/mAP50-95(M)': 0.26637, 'val/box_loss': 1.38808, 'val/seg_loss': 1.44468, 'val/cls_loss': 0.67167, 'val/dfl_loss': 1.05757, 'fitness': 0.60689}
# Tuner: Best fitness model is runs\segment\train132
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.0076
# lrf: 0.01098
# momentum: 0.91641
# weight_decay: 0.00043
# warmup_epochs: 1.91407
# warmup_momentum: 0.84567
# box: 8.03111
# cls: 0.28108
# dfl: 1.61628
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07192
# scale: 0.32029
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.26221
# mosaic: 0.848
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 16/20 with hyperparameters: {'lr0': 0.0076, 'lrf': 0.01046, 'momentum': 0.91765, 'weight_decay': 0.00043, 'warmup_epochs': 1.91043, 'warmup_momentum': 0.88233, 'box': 7.93639, 'cls': 0.27671, 'dfl': 1.61628, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.06591, 'scale': 0.3479, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.23487, 'mosaic': 0.80513, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 16/20 iterations complete  (27786.33s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.60689 observed at iteration 14
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.80262, 'metrics/recall(B)': 0.42296, 'metrics/mAP50(B)': 0.48825, 'metrics/mAP50-95(B)': 0.30346, 'metrics/precision(M)': 0.77848, 'metrics/recall(M)': 0.39397, 'metrics/mAP50(M)': 0.45219, 'metrics/mAP50-95(M)': 0.26637, 'val/box_loss': 1.38808, 'val/seg_loss': 1.44468, 'val/cls_loss': 0.67167, 'val/dfl_loss': 1.05757, 'fitness': 0.60689}
# Tuner: Best fitness model is runs\segment\train132
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.0076
# lrf: 0.01098
# momentum: 0.91641
# weight_decay: 0.00043
# warmup_epochs: 1.91407
# warmup_momentum: 0.84567
# box: 8.03111
# cls: 0.28108
# dfl: 1.61628
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07192
# scale: 0.32029
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.26221
# mosaic: 0.848
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 17/20 with hyperparameters: {'lr0': 0.00806, 'lrf': 0.01191, 'momentum': 0.92959, 'weight_decay': 0.00044, 'warmup_epochs': 1.91407, 'warmup_momentum': 0.81818, 'box': 8.04338, 'cls': 0.24934, 'dfl': 1.63666, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.07371, 'scale': 0.3357, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.26221, 'mosaic': 0.90014, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 17/20 iterations complete  (29072.22s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.60689 observed at iteration 14
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.80262, 'metrics/recall(B)': 0.42296, 'metrics/mAP50(B)': 0.48825, 'metrics/mAP50-95(B)': 0.30346, 'metrics/precision(M)': 0.77848, 'metrics/recall(M)': 0.39397, 'metrics/mAP50(M)': 0.45219, 'metrics/mAP50-95(M)': 0.26637, 'val/box_loss': 1.38808, 'val/seg_loss': 1.44468, 'val/cls_loss': 0.67167, 'val/dfl_loss': 1.05757, 'fitness': 0.60689}
# Tuner: Best fitness model is runs\segment\train132
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.0076
# lrf: 0.01098
# momentum: 0.91641
# weight_decay: 0.00043
# warmup_epochs: 1.91407
# warmup_momentum: 0.84567
# box: 8.03111
# cls: 0.28108
# dfl: 1.61628
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07192
# scale: 0.32029
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.26221
# mosaic: 0.848
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 18/20 with hyperparameters: {'lr0': 0.0076, 'lrf': 0.01169, 'momentum': 0.98, 'weight_decay': 0.00041, 'warmup_epochs': 1.91407, 'warmup_momentum': 0.89461, 'box': 6.55313, 'cls': 0.31243, 'dfl': 1.58686, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.07675, 'scale': 0.33335, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.26221, 'mosaic': 0.81892, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 18/20 iterations complete  (30371.99s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.60689 observed at iteration 14
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.80262, 'metrics/recall(B)': 0.42296, 'metrics/mAP50(B)': 0.48825, 'metrics/mAP50-95(B)': 0.30346, 'metrics/precision(M)': 0.77848, 'metrics/recall(M)': 0.39397, 'metrics/mAP50(M)': 0.45219, 'metrics/mAP50-95(M)': 0.26637, 'val/box_loss': 1.38808, 'val/seg_loss': 1.44468, 'val/cls_loss': 0.67167, 'val/dfl_loss': 1.05757, 'fitness': 0.60689}
# Tuner: Best fitness model is runs\segment\train132
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.0076
# lrf: 0.01098
# momentum: 0.91641
# weight_decay: 0.00043
# warmup_epochs: 1.91407
# warmup_momentum: 0.84567
# box: 8.03111
# cls: 0.28108
# dfl: 1.61628
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07192
# scale: 0.32029
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.26221
# mosaic: 0.848
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 19/20 with hyperparameters: {'lr0': 0.01049, 'lrf': 0.0127, 'momentum': 0.9521, 'weight_decay': 0.0004, 'warmup_epochs': 2.46915, 'warmup_momentum': 0.54545, 'box': 9.792, 'cls': 0.23041, 'dfl': 2.01929, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.08938, 'scale': 0.18096, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.28423, 'mosaic': 0.80461, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 19/20 iterations complete  (31654.82s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.60689 observed at iteration 14
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.80262, 'metrics/recall(B)': 0.42296, 'metrics/mAP50(B)': 0.48825, 'metrics/mAP50-95(B)': 0.30346, 'metrics/precision(M)': 0.77848, 'metrics/recall(M)': 0.39397, 'metrics/mAP50(M)': 0.45219, 'metrics/mAP50-95(M)': 0.26637, 'val/box_loss': 1.38808, 'val/seg_loss': 1.44468, 'val/cls_loss': 0.67167, 'val/dfl_loss': 1.05757, 'fitness': 0.60689}
# Tuner: Best fitness model is runs\segment\train132
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.0076
# lrf: 0.01098
# momentum: 0.91641
# weight_decay: 0.00043
# warmup_epochs: 1.91407
# warmup_momentum: 0.84567
# box: 8.03111
# cls: 0.28108
# dfl: 1.61628
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07192
# scale: 0.32029
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.26221
# mosaic: 0.848
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 20/20 with hyperparameters: {'lr0': 0.00745, 'lrf': 0.01098, 'momentum': 0.9196, 'weight_decay': 0.00042, 'warmup_epochs': 1.6657, 'warmup_momentum': 0.89826, 'box': 8.03111, 'cls': 0.27326, 'dfl': 1.49366, 'hsv_h': 0.0, 'hsv_s': 0.0, 'hsv_v': 0.0, 'degrees': 0.0, 'translate': 0.07181, 'scale': 0.32029, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.28091, 'mosaic': 0.8812, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\segment\tune15\tune_scatter_plots.png
# Saved runs\segment\tune15\tune_fitness.png
#
# Tuner: 20/20 iterations complete  (32955.03s)
# Tuner: Results saved to runs\segment\tune15
# Tuner: Best fitness=0.60689 observed at iteration 14
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.80262, 'metrics/recall(B)': 0.42296, 'metrics/mAP50(B)': 0.48825, 'metrics/mAP50-95(B)': 0.30346, 'metrics/precision(M)': 0.77848, 'metrics/recall(M)': 0.39397, 'metrics/mAP50(M)': 0.45219, 'metrics/mAP50-95(M)': 0.26637, 'val/box_loss': 1.38808, 'val/seg_loss': 1.44468, 'val/cls_loss': 0.67167, 'val/dfl_loss': 1.05757, 'fitness': 0.60689}
# Tuner: Best fitness model is runs\segment\train132
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\segment\tune15\best_hyperparameters.yaml'
#
# lr0: 0.0076
# lrf: 0.01098
# momentum: 0.91641
# weight_decay: 0.00043
# warmup_epochs: 1.91407
# warmup_momentum: 0.84567
# box: 8.03111
# cls: 0.28108
# dfl: 1.61628
# hsv_h: 0.0
# hsv_s: 0.0
# hsv_v: 0.0
# degrees: 0.0
# translate: 0.07192
# scale: 0.32029
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.26221
# mosaic: 0.848
# mixup: 0.0
# copy_paste: 0.0

# %%
model = YOLO("runs/segment/tune14/weights/best.pt")

# %%
# Validate the model
metrics = model.val(workers=1)  # no arguments needed, dataset and settings remembered
# Out:
# Ultralytics YOLOv8.0.208  Python-3.9.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4096MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11781148 parameters, 0 gradients, 42.4 GFLOPs
# val: Scanning D:\Code\Screen2SOM-Training\YOLO_Datasets\ApplicationLevel_train\val\labels.cache... 41 images, 1 backgrounds, 0 corrupt: 100%|██████████| 41/41 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:45<00:00, 15.32s/it]
#                    all         41        143      0.842      0.251        0.3      0.126      0.853      0.189       0.22      0.079
#                 Header         41         51      0.711      0.338      0.488      0.232      0.739      0.255      0.343      0.109
#                Toolbar         41         15          1          0     0.0241    0.00938          1          0     0.0191    0.00873
#         BrowserToolbar         41         24      0.657      0.667       0.63      0.241      0.672        0.5      0.511      0.196
#              Scrollbar         41         53          1          0     0.0584     0.0204          1          0    0.00569    0.00274
# Speed: 2.4ms preprocess, 22.9ms inference, 0.0ms loss, 7.1ms postprocess per image
# Results saved to runs\segment\val9

# %%
metrics.seg.map    # map50-95
metrics.seg.map50  # map50
metrics.seg.map75  # map75
metrics.seg.maps   # a list contains map50-95 of each category
# Out:
# array([    0.19274,     0.32869,     0.40419,     0.39927,       0.561,     0.28032,     0.10029,     0.16814,     0.26469,     0.19651,     0.35886,     0.31838,     0.15703])

# %%
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# array([    0.44217,     0.57988,      0.5628,     0.66923,     0.72803,     0.39053,     0.33478,     0.53026,     0.41717,     0.49925,     0.55777,     0.43547,      0.2592])

# %%
inference = model("../YOLO_Datasets/Elementlevel_train/val/images/Captura de pantalla (44)_2.jpg", save=True)
# Out:
# image 1/1 d:\Code\Screen2SOM-Training\Training\..\YOLO_Datasets\Elementlevel_train\val\images\Captura de pantalla (44)_2.jpg: 384x640 33 WebIcons, 4 Icons, 3 BtnPills, 3 TextInputs, 2 Links, 29.0ms
# Speed: 3.0ms preprocess, 29.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\segment\predict
